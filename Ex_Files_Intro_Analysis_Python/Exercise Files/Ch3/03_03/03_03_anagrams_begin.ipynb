# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='UTF-8'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordlist)
# Out:
# 235886

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron'.lower()
# Out:
# 'aaron'

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordunique = list(set(wordclean))

# %%
wordunique
# Out:
# ['ossetian',
#  'underbarber',
#  'shiest',
#  'superdural',
#  'overthick',
#  'damascenine',
#  'calamiferous',
#  'constitute',
#  'genitor',
#  'outwake',
#  'cantala',
#  'optionee',
#  'venesector',
#  'erethic',
#  'film',
#  'megalocornea',
#  'colchis',
#  'palenque',
#  'cowdie',
#  'brethren',
#  'servilely',
#  'philomuse',
#  'thialdine',
#  'septiform',
#  'silicoacetic',
#  'polarographic',
#  'chaplaincy',
#  'tariffize',
#  'trophically',
#  'kupper',
#  'windesheimer',
#  'citizenism',
#  'phaeophore',
#  'vouchsafement',
#  'dubb',
#  'pseudocortex',
#  'upraisal',
#  'krona',
#  'endophagous',
#  'gravegarth',
#  'mataeological',
#  'allele',
#  'aphylly',
#  'routineer',
#  'unshewed',
#  'sensile',
#  'anthracitization',
#  'bookcase',
#  'sermoner',
#  'untranslated',
#  'sleeking',
#  'tearoom',
#  'ebenales',
#  'granulitize',
#  'mousing',
#  'thuggee',
#  'adipsous',
#  'pulasan',
#  'mandruka',
#  'brontozoum',
#  'polycyclic',
#  'micrurgy',
# ...

# %%
wordunique.sort()

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
wordclean = [word.strip().lower() for word in open('words','r')]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words','r')])))

# %%
wordclean[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
sorted('lives')
# Out:
# ['e', 'i', 'l', 's', 'v']

# %%
sorted('lives') == sorted('elvis')
# Out:
# True

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
'/'.join(['a','b','c'])
# Out:
# 'a/b/c'

# %%
def anagram(myword):
    return [word for word in wordclean if signature(word) == signature(myword)]

# %%
anagram('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
# %timeit anagram('dictionary')
# Out:
# 267 ms ± 5.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
words_bysig = {}

# %%
for word in wordclean:
    words_bysig[signature(word)].append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-7d1ef213111f> in <module>
#       1 for word in wordclean:
# ----> 2     words_bysig[signature(word)].append(word)
#
# KeyError: 'a'

# %%
import collections

# %%
words_bysig = collections.defaultdict(list)

# %%
for word in wordclean:
    words_bysig[signature(word)].append(word)

# %%
words_bysig
# Out:
# defaultdict(list,
#             {'a': ['a'],
#              'aa': ['aa'],
#              'aal': ['aal', 'ala'],
#              'aaiil': ['aalii'],
#              'aam': ['aam', 'ama'],
#              'aain': ['aani'],
#              'aaadkrrv': ['aardvark'],
#              'aadflorw': ['aardwolf'],
#              'aanor': ['aaron'],
#              'aacinor': ['aaronic', 'nicarao', 'ocarina'],
#              'aaacilnor': ['aaronical'],
#              'aaeinort': ['aaronite', 'aeration'],
#              'aaciinort': ['aaronitic'],
#              'aaru': ['aaru', 'aura'],
#              'ab': ['ab', 'ba'],
#              'aab': ['aba', 'baa'],
#              'aabbdeh': ['ababdeh'],
#              'aaabbu': ['ababua'],
#              'aabc': ['abac', 'caba'],
#              'aaabc': ['abaca'],
#              'aaabcet': ['abacate'],
#              'aaabcy': ['abacay'],
#              'aaabceint': ['abacinate'],
#              'aaabciinnot': ['abacination'],
# ...

# %%
def anagram_fast(myword):
    return words_bysig[signature(myword)]

# %%
anagram_fast('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
# %timeit anagram_fast('dictionary')
# Out:
# 634 ns ± 8.76 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit anagrams_all = {word: anagram_fast(word) for word in wordlist if len(anagram_fast(word)) > 1}
# Out:
# 232 ms ± 12.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
anagrams_all = {word: anagram_fast(word) for word in wordlist if len(anagram_fast(word)) > 1}

# %%
anagrams_all
# Out:
# {}

# %%
wordlist
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n',
#  'Aaronic\n',
#  'Aaronical\n',
#  'Aaronite\n',
#  'Aaronitic\n',
#  'Aaru\n',
#  'Ab\n',
#  'aba\n',
#  'Ababdeh\n',
#  'Ababua\n',
#  'abac\n',
#  'abaca\n',
#  'abacate\n',
#  'abacay\n',
#  'abacinate\n',
#  'abacination\n',
#  'abaciscus\n',
#  'abacist\n',
#  'aback\n',
#  'abactinal\n',
#  'abactinally\n',
#  'abaction\n',
#  'abactor\n',
#  'abaculus\n',
#  'abacus\n',
#  'Abadite\n',
#  'abaff\n',
#  'abaft\n',
#  'abaisance\n',
#  'abaiser\n',
#  'abaissed\n',
#  'abalienate\n',
#  'abalienation\n',
#  'abalone\n',
#  'Abama\n',
#  'abampere\n',
#  'abandon\n',
#  'abandonable\n',
#  'abandoned\n',
#  'abandonedly\n',
#  'abandonee\n',
#  'abandoner\n',
#  'abandonment\n',
#  'Abanic\n',
#  'Abantes\n',
#  'abaptiston\n',
#  'Abarambo\n',
#  'Abaris\n',
#  'abarthrosis\n',
#  'abarticular\n',
#  'abarticulation\n',
#  'abas\n',
#  'abase\n',
# ...

# %%
wordclean
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
# ...

# %%
anagrams_all = {word: anagram_fast(word) for word in wordclean if len(anagram_fast(word)) > 1}

# %%
anagrams_all
# Out:
# {'aal': ['aal', 'ala'],
#  'aam': ['aam', 'ama'],
#  'aaronic': ['aaronic', 'nicarao', 'ocarina'],
#  'aaronite': ['aaronite', 'aeration'],
#  'aaru': ['aaru', 'aura'],
#  'ab': ['ab', 'ba'],
#  'aba': ['aba', 'baa'],
#  'abac': ['abac', 'caba'],
#  'abactor': ['abactor', 'acrobat'],
#  'abaft': ['abaft', 'bafta'],
#  'abalone': ['abalone', 'balonea'],
#  'abandoner': ['abandoner', 'reabandon'],
#  'abanic': ['abanic', 'bianca'],
#  'abaris': ['abaris', 'arabis'],
#  'abas': ['abas', 'saba'],
#  'abaser': ['abaser', 'abrase'],
#  'abate': ['abate', 'ateba', 'batea', 'beata'],
#  'abater': ['abater', 'artabe', 'eartab', 'trabea'],
#  'abb': ['abb', 'bab'],
#  'abba': ['abba', 'baba'],
#  'abbey': ['abbey', 'bebay'],
#  'abby': ['abby', 'baby'],
#  'abdat': ['abdat', 'batad'],
#  'abdiel': ['abdiel', 'baldie'],
#  'abdominovaginal': ['abdominovaginal', 'vaginoabdominal'],
#  'abdominovesical': ['abdominovesical', 'vesicoabdominal'],
#  'abe': ['abe', 'bae', 'bea'],
# ...

# %%
count_anagrams = {word: len(anagram_fast(word)) for word in wordclean if len(anagram_fast(word)) > 1}

# %%
count_anagrams
# Out:
# {'aal': 2,
#  'aam': 2,
#  'aaronic': 3,
#  'aaronite': 2,
#  'aaru': 2,
#  'ab': 2,
#  'aba': 2,
#  'abac': 2,
#  'abactor': 2,
#  'abaft': 2,
#  'abalone': 2,
#  'abandoner': 2,
#  'abanic': 2,
#  'abaris': 2,
#  'abas': 2,
#  'abaser': 2,
#  'abate': 4,
#  'abater': 4,
#  'abb': 2,
#  'abba': 2,
#  'abbey': 2,
#  'abby': 2,
#  'abdat': 2,
#  'abdiel': 2,
#  'abdominovaginal': 2,
#  'abdominovesical': 2,
#  'abe': 3,
#  'abed': 3,
#  'abel': 7,
#  'abele': 2,
#  'abelian': 2,
#  'abenteric': 2,
#  'aberia': 3,
#  'abet': 4,
#  'abetment': 2,
#  'abettor': 2,
#  'abhorrent': 2,
#  'abhorrer': 2,
#  'abider': 2,
#  'abies': 2,
#  'abilla': 2,
#  'abilo': 2,
#  'abir': 3,
#  'abiston': 2,
#  'abiuret': 4,
#  'abkar': 2,
#  'abkhas': 2,
#  'ablactate': 2,
#  'ablare': 3,
#  'ablastemic': 2,
#  'ablation': 2,
#  'ablaut': 2,
#  'able': 7,
#  'ableness': 3,
#  'ablepsia': 2,
#  'abler': 5,
#  'ablest': 3,
#  'abloom': 2,
#  'ablow': 3,
#  'ablude': 2,
#  'abluent': 2,
#  'ablution': 2,
# ...

# %%
max([len(anagram_fast(word)) for word in wordclean if len(anagram_fast(word))])
# Out:
# 10
