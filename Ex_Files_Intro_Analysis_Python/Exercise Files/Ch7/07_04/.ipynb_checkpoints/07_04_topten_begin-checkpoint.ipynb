# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn

# %%
# %matplotlib inline

# %%
import zipfile
zipfile.ZipFile('names.zip').extractall('.')

# %%
import os
os.listdir('names')
# Out:
# ['yob2000.txt',
#  'yob2014.txt',
#  'yob1938.txt',
#  'yob1910.txt',
#  'yob1904.txt',
#  'yob1905.txt',
#  'yob1911.txt',
#  'yob1939.txt',
#  'yob2001.txt',
#  'yob2003.txt',
#  'yob1907.txt',
#  'yob1913.txt',
#  'yob1898.txt',
#  'yob1899.txt',
#  'yob1912.txt',
#  'yob1906.txt',
#  'yob2002.txt',
#  'yob2012.txt',
#  'yob2006.txt',
#  'yob1902.txt',
#  'yob1916.txt',
#  'yob1889.txt',
#  'yob1888.txt',
#  'yob1917.txt',
#  'yob1903.txt',
#  'yob2007.txt',
#  'yob2013.txt',
#  'yob2005.txt',
#  'yob2011.txt',
#  'yob1915.txt',
#  'yob1901.txt',
#  'yob1929.txt',
#  'yob1928.txt',
#  'yob1900.txt',
#  'yob1914.txt',
#  'yob2010.txt',
#  'yob2004.txt',
#  'yob1973.txt',
#  'yob1967.txt',
#  'yob1998.txt',
#  'yob1999.txt',
#  'yob1966.txt',
#  'yob1972.txt',
#  'yob1958.txt',
#  'yob1964.txt',
#  'yob1970.txt',
#  'yob1971.txt',
#  'yob1965.txt',
#  'yob1959.txt',
#  'yob1961.txt',
#  'yob1975.txt',
#  'yob1949.txt',
#  'yob1948.txt',
#  'yob1974.txt',
#  'yob1960.txt',
#  'yob1976.txt',
#  'yob1962.txt',
#  'yob1989.txt',
#  'yob1988.txt',
#  'yob1963.txt',
#  'yob1977.txt',
#  'yob1952.txt',
#  'yob1946.txt',
#  'yob1991.txt',
#  'yob1985.txt',
#  'yob1984.txt',
#  'yob1990.txt',
#  'yob1947.txt',
#  'yob1953.txt',
#  'yob1979.txt',
#  'yob1945.txt',
#  'yob1951.txt',
#  'yob1986.txt',
#  'yob1992.txt',
#  'yob1993.txt',
#  'yob1987.txt',
#  'yob1950.txt',
#  'yob1944.txt',
#  'yob1978.txt',
#  'yob1940.txt',
#  'yob1954.txt',
#  'yob1968.txt',
#  'yob1983.txt',
#  'yob1997.txt',
#  'yob1996.txt',
#  'yob1982.txt',
#  'yob1969.txt',
#  'yob1955.txt',
#  'yob1941.txt',
#  'yob1957.txt',
#  'yob1943.txt',
#  'yob1994.txt',
#  'yob1980.txt',
#  'yob1981.txt',
#  'yob1995.txt',
#  'yob1942.txt',
#  'yob1956.txt',
#  'yob2009.txt',
#  'yob1919.txt',
#  'yob1931.txt',
#  'yob1925.txt',
#  'yob1886.txt',
#  'yob1892.txt',
#  'yob1893.txt',
#  'yob1887.txt',
#  'yob1924.txt',
#  'yob1930.txt',
#  'yob1918.txt',
#  'yob2008.txt',
#  'yob1926.txt',
#  'yob1932.txt',
#  'yob1891.txt',
#  'yob1885.txt',
#  'NationalReadMe.pdf',
#  'yob1884.txt',
#  'yob1890.txt',
#  'yob1933.txt',
#  'yob1927.txt',
#  'yob1923.txt',
#  'yob1937.txt',
#  'yob1894.txt',
#  'yob1880.txt',
#  'yob1881.txt',
#  'yob1895.txt',
#  'yob1936.txt',
#  'yob1922.txt',
#  'yob1934.txt',
#  'yob1920.txt',
#  'yob1908.txt',
#  'yob1883.txt',
#  'yob1897.txt',
#  'yob1896.txt',
#  'yob1882.txt',
#  'yob1909.txt',
#  'yob1921.txt',
#  'yob1935.txt']

# %%
open('names/yob2011.txt','r').readlines()[:10]
# Out:
# ['Sophia,F,21816\n',
#  'Isabella,F,19870\n',
#  'Emma,F,18777\n',
#  'Olivia,F,17294\n',
#  'Ava,F,15480\n',
#  'Emily,F,14236\n',
#  'Abigail,F,13229\n',
#  'Madison,F,12360\n',
#  'Mia,F,11512\n',
#  'Chloe,F,10970\n']

# %%
names2011 = pd.read_csv('names/yob2011.txt')

# %%
names2011.head()
# Out:
#      Sophia  F  21816
# 0  Isabella  F  19870
# 1      Emma  F  18777
# 2    Olivia  F  17294
# 3       Ava  F  15480
# 4     Emily  F  14236

# %%
names2011 = pd.read_csv('names/yob2011.txt',names=['name','sex','number'])

# %%
names2011.head()
# Out:
#        name sex  number
# 0    Sophia   F   21816
# 1  Isabella   F   19870
# 2      Emma   F   18777
# 3    Olivia   F   17294
# 4       Ava   F   15480

# %%
names_all = []

for year in range(1880,2014+1):
    names_all.append(pd.read_csv('names/yob{}.txt'.format(year),names=['name','sex','number']))
    names_all[-1]['year'] = year

allyears = pd.concat(names_all)

# %%
allyears.head()
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
allyears.tail()
# Out:
#           name sex  number  year
# 33039   Zykeem   M       5  2014
# 33040   Zymeer   M       5  2014
# 33041  Zymiere   M       5  2014
# 33042    Zyran   M       5  2014
# 33043    Zyrin   M       5  2014

# %%
allyears_indexed = allyears.set_index(['sex','name','year']).sort_index()

# %%
allyears_indexed
# Out:
#                     number
# sex name      year
# F   Aabha     2011       7
#               2012       5
#               2014       9
#     Aabriella 2008       5
#               2014       5
#     Aaden     2009       5
#     Aadhira   2012       6
#               2013      10
#               2014      13
#     Aadhya    2007      10
#               2008       9
#               2009      18
#               2010      19
#               2011      52
#               2012     110
#               2013     172
#               2014     249
#     Aadi      2006       5
#               2012       5
#               2013       6
#     Aadison   2009       6
#               2012       5
#     Aaditri   2010       5
#               2012       5
#               2013       6
#               2014      10
#     Aadrika   2013       5
#               2014       5
#     Aadvika   2013       6
#               2014       7
# ...                    ...
# M   Zyshawn   2008      14
#               2009       7
#               2010       9
#               2011       5
#               2012      10
#               2013      13
#               2014       6
#     Zyshon    1998       8
#               2001       6
#               2005       5
#     Zyshonne  1998      26
#               1999      30
#               2000      17
#               2001      12
#               2002       9
#               2003       7
#     Zytaevius 2012       5
#     Zytaveon  2011       8
#               2014       7
#     Zytavion  2011       5
#     Zytavious 2002       6
#               2004       6
#               2005       5
#               2006       7
#               2007       6
#               2009       7
#               2010       6
#     Zyvion    2009       5
#     Zyyon     2014       6
#     Zzyzx     2010       5
#
# [1825433 rows x 1 columns]

# %%
allyears_indexed.loc['F','Mary']
# Out:
#       number
# year
# 1880    7065
# 1881    6919
# 1882    8148
# 1883    8012
# 1884    9217
# 1885    9128
# 1886    9890
# 1887    9888
# 1888   11754
# 1889   11648
# 1890   12078
# 1891   11703
# 1892   13173
# 1893   12784
# 1894   13151
# 1895   13446
# 1896   13811
# 1897   13413
# 1898   14406
# 1899   13172
# 1900   16707
# 1901   13136
# 1902   14486
# 1903   14275
# 1904   14962
# 1905   16067
# 1906   16370
# 1907   17580
# 1908   18666
# 1909   19259
# ...      ...
# 1985    9239
# 1986    8503
# 1987    8395
# 1988    8508
# 1989    8642
# 1990    8664
# 1991    8756
# 1992    8452
# 1993    8110
# 1994    7746
# 1995    7433
# 1996    6942
# 1997    6626
# 1998    6429
# 1999    6359
# 2000    6182
# 2001    5724
# 2002    5450
# 2003    5009
# 2004    4803
# 2005    4447
# 2006    4081
# 2007    3673
# 2008    3490
# 2009    3154
# 2010    2862
# 2011    2701
# 2012    2565
# 2013    2632
# 2014    2611
#
# [135 rows x 1 columns]

# %%
def plotname(sex,name):
    data = allyears_indexed.loc[sex,name]
    
    pp.plot(data.index,data.values)

# %%
pp.figure(figsize=(12,2.5))

names = ['Michael','John','David','Martin']

for name in names:
    plotname('M',name)

pp.legend(names)

# %%
pp.figure(figsize=(12,2.5))

names = ['Emily','Anna','Claire','Elizabeth']

for name in names:
    plotname('F',name)

pp.legend(names)

# %%
pp.figure(figsize=(12,2.5))

names = ['Chiara','Claire','Clare','Clara','Ciara']

for name in names:
    plotname('F',name)

pp.legend(names)

# %%
allyears_indexed.loc['F'].loc[names].head()
# Out:
#              number
# name   year
# Chiara 1959       9
#        1960       5
#        1962       8
#        1963       8
#        1964      12

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).head()
# Out:
#      number
# name Chiara Ciara Claire   Clara Clare
# year
# 1880    NaN   NaN   21.0  1226.0  15.0
# 1881    NaN   NaN   23.0  1242.0  20.0
# 1882    NaN   NaN   30.0  1490.0  21.0
# 1883    NaN   NaN   38.0  1548.0  22.0
# 1884    NaN   NaN   33.0  1852.0  38.0

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0).head()
# Out:
#      number
# name Chiara Ciara Claire   Clara Clare
# year
# 1880    0.0   0.0   21.0  1226.0  15.0
# 1881    0.0   0.0   23.0  1242.0  20.0
# 1882    0.0   0.0   30.0  1490.0  21.0
# 1883    0.0   0.0   38.0  1548.0  22.0
# 1884    0.0   0.0   33.0  1852.0  38.0

# %%
variants = allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0)

# %%
pp.figure(figsize=(12,2.5))

pp.stackplot(variants.index,variants.values.T)
# Out:
# [<matplotlib.collections.PolyCollection at 0x1a2e53e7b8>,
#  <matplotlib.collections.PolyCollection at 0x1a2e53ea20>,
#  <matplotlib.collections.PolyCollection at 0x1a2e53ec88>,
#  <matplotlib.collections.PolyCollection at 0x1a2e53eef0>,
#  <matplotlib.collections.PolyCollection at 0x1a2e54c198>]

# %%
pp.figure(figsize=(12,2.5))

palette = seaborn.color_palette()
pp.stackplot(variants.index,variants.values.T,colors=palette)

for i,name in enumerate(names):
    pp.text(1882,5000 + 800*i,name,color=palette[i])

# %%
allyears_indexed.loc['M',:,2008].sort_values('number', ascending=False).head()
# Out:
#                   number
# sex name    year
# M   Jacob   2008   22568
#     Michael 2008   20590
#     Ethan   2008   20196
#     Joshua  2008   19186
#     Daniel  2008   18985

# %%
pop2008 = allyears_indexed.loc['M',:,2008].sort_values('number', ascending=False).head()

# %%
pop2008.reset_index().drop(['sex', 'year', 'number'], axis=1).head()
# Out:
#       name
# 0    Jacob
# 1  Michael
# 2    Ethan
# 3   Joshua
# 4   Daniel

# %%
pop2008
# Out:
#                   number
# sex name    year
# M   Jacob   2008   22568
#     Michael 2008   20590
#     Ethan   2008   20196
#     Joshua  2008   19186
#     Daniel  2008   18985

# %%
def topten(sex, year):
    simple = allyears_indexed.loc[sex,:,year].sort_values('number', ascending=False).reset_index()
    simple = simple.drop(['sex', 'year', 'number'], axis=1).head(10)
    
    simple.columns = [year]
    
    return simple

# %%
topten('M',2009)
# Out:
#           2009
# 0        Jacob
# 1        Ethan
# 2      Michael
# 3    Alexander
# 4      William
# 5       Joshua
# 6       Daniel
# 7       Jayden
# 8         Noah
# 9  Christopher

# %%
def toptens(sex, year0, year1):
    years = [topten(sex,year) for year in range(year0, year1+1)]
    
    return years[0].join(years[1:])

# %%
toptens('M',2000,2010)
# Out:
#           2000         2001         2002         2003         2004  \
# 0        Jacob        Jacob        Jacob        Jacob        Jacob
# 1      Michael      Michael      Michael      Michael      Michael
# 2      Matthew      Matthew       Joshua       Joshua       Joshua
# 3       Joshua       Joshua      Matthew      Matthew      Matthew
# 4  Christopher  Christopher        Ethan       Andrew        Ethan
# 5     Nicholas     Nicholas       Andrew        Ethan       Andrew
# 6       Andrew       Andrew       Joseph       Joseph       Daniel
# 7       Joseph       Joseph  Christopher       Daniel      William
# 8       Daniel       Daniel     Nicholas  Christopher       Joseph
# 9        Tyler      William       Daniel      Anthony  Christopher
#
#           2005         2006         2007         2008         2009       2010
# 0        Jacob        Jacob        Jacob        Jacob        Jacob      Jacob
# 1      Michael      Michael      Michael      Michael        Ethan      Ethan
# 2       Joshua       Joshua        Ethan        Ethan      Michael    Michael
# 3      Matthew        Ethan       Joshua       Joshua    Alexander     Jayden
# 4        Ethan      Matthew       Daniel       Daniel      William    William
# 5       Andrew       Daniel  Christopher    Alexander       Joshua  Alexander
# 6       Daniel       Andrew      Anthony      William       Daniel       Noah
# 7      Anthony  Christopher      William      Anthony       Jayden     Daniel
# 8       Joseph      Anthony      Matthew  Christopher         Noah      Aiden
# 9  Christopher      William       Andrew      Matthew  Christopher    Anthony

# %%
toptens('F',1985,1995)
# Out:
#         1985       1986       1987       1988       1989       1990  \
# 0    Jessica    Jessica    Jessica    Jessica    Jessica    Jessica
# 1     Ashley     Ashley     Ashley     Ashley     Ashley     Ashley
# 2   Jennifer     Amanda     Amanda     Amanda   Brittany   Brittany
# 3     Amanda   Jennifer   Jennifer      Sarah     Amanda     Amanda
# 4      Sarah      Sarah      Sarah   Jennifer      Sarah   Samantha
# 5  Stephanie  Stephanie  Stephanie   Brittany   Samantha      Sarah
# 6     Nicole     Nicole   Brittany  Stephanie   Jennifer  Stephanie
# 7    Heather   Brittany     Nicole   Samantha  Stephanie   Jennifer
# 8  Elizabeth    Heather    Heather     Nicole     Lauren  Elizabeth
# 9      Megan  Elizabeth  Elizabeth  Elizabeth  Elizabeth     Lauren
#
#         1991       1992       1993       1994       1995
# 0     Ashley     Ashley    Jessica    Jessica    Jessica
# 1    Jessica    Jessica     Ashley     Ashley     Ashley
# 2   Brittany     Amanda      Sarah      Emily      Emily
# 3     Amanda   Brittany   Samantha   Samantha   Samantha
# 4   Samantha      Sarah      Emily      Sarah      Sarah
# 5      Sarah   Samantha   Brittany     Taylor     Taylor
# 6  Stephanie      Emily     Taylor   Brittany     Hannah
# 7   Jennifer  Stephanie     Amanda     Amanda   Brittany
# 8  Elizabeth  Elizabeth  Elizabeth  Elizabeth     Amanda
# 9      Emily      Megan  Stephanie      Megan  Elizabeth

# %%
# Out:
#         1995       1996       1997       1998       1999       2000
# 0    Jessica      Emily      Emily      Emily      Emily      Emily
# 1     Ashley    Jessica    Jessica     Hannah     Hannah     Hannah
# 2      Emily     Ashley     Ashley   Samantha     Alexis    Madison
# 3   Samantha      Sarah      Sarah      Sarah      Sarah     Ashley
# 4      Sarah   Samantha     Hannah     Ashley   Samantha      Sarah
# 5     Taylor     Taylor   Samantha     Alexis     Ashley     Alexis
# 6     Hannah     Hannah     Taylor     Taylor    Madison   Samantha
# 7   Brittany     Alexis     Alexis    Jessica     Taylor    Jessica
# 8     Amanda     Rachel  Elizabeth    Madison    Jessica  Elizabeth
# 9  Elizabeth  Elizabeth    Madison  Elizabeth  Elizabeth     Taylor

# %%
plotname('F','Alexis')

# %%
toptens('F',1985,1995).stack().head()
# Out:
# 0  1985    Jessica
#    1986    Jessica
#    1987    Jessica
#    1988    Jessica
#    1989    Jessica
# dtype: object

# %%
toptens('F',1985,1995).stack().value_counts()a
# Out:
# Jessica      11
# Amanda       11
# Sarah        11
# Elizabeth    11
# Ashley       11
# Brittany     10
# Stephanie     9
# Samantha      8
# Jennifer      7
# Emily         5
# Nicole        4
# Megan         3
# Heather       3
# Taylor        3
# Lauren        2
# Hannah        1
# dtype: int64

# %%
popular = toptens('F',1985,1995).stack().value_counts().index[:6]

# %%
pp.figure(figsize=(12,2.5))

for name in popular:
    plotname('F', name)
    
pp.legend(popular)
